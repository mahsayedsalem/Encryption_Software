# %% [markdown]
# # Security Project
#
# This notebook is an implementation for the AES algorithm written in vanilla python3 and some ciphers using pycipher library
#
# <h3> Problem Statement: </h3>
#
# An encryption ready-to-production software which uses encryption algorithms to encrypt plain texts using multiple encryption algorithms, one of which is written from scratch while the other encryptions are produced using an encryption library.
#
#
# <h4>Steps: </h4>
# 1.	Take a plain message and a key
# 2.	Divide the plain message into 128bits and pad the final remaining. .
# 3.	Translate them into Hex
# 4.	Get the first RoundKey:
#     •	Divide the key into 4 parts
#     •	Left-shift to the last part
#     •	Byte Substitution to the output of the last step
#     •	Add Round constant to the output of the last step
# 5.	Xor between the first part of the key and the output of the last step
# 6.	Xor between the second part of the key and the output of the last step
# 7.	Xor between the third part of the key and the output of the last step
# 8.	Xor between the fourth part of the key and the output of the last step
# 9.	Concat the output of the last four steps and this gives us the first RoundKey.
# 10.	Use this Roundkey as a key to iterate the steps again till we get 5 RoundKeys.
# 11.	Xor between state message and the first roundkey
# 12.	In each round we make:
#     •	Substitution
#     •	Shift-Rows
#     •	Mix-Columns
#     •	Add RoundKey
# 13.	In the final step we make all the steps but the mix columns, then we concat the message and this is our encrypted message.
#
#
# <h4>Functions Developed for AES: </h4>
# 1.	lettersToHex(message): <i>Translate strings into hexadecimals.</i>
# 2.	split_string(message): <i>split strings into arrays of 128bits.</i>
# 3.	format_arr_hex(arr_message): <i>format the array.</i>
# 4.	RoundKeys(key): <i>produces the roundkeys needed.</i>
# 5.	Xor_hex(arr_str1, arr_str2): <i>xor operations between two arrays of strings.</i>
# 6.	Sbox_number(stringx): <i>produces the place of the value needed from the sbox array.</i>
# 7.	AddRoundKey(message,key): <i>Adds Roundkey to message.</i>
# 8.	shiftRows(single_state): <i>Shifts rows of a state.</i>
# 9.	galois_mult(a, b): <i>Copied function that makes galois multiplication.</i>
# 10.	MixColumns(state): <i>Mixes columns of a state.</i>
# 11.	Aes_encrypt(message,key): <i>The main aes algorithm utilizing the previous functions.</i>
#
# <h4>Ciphers Algorithms: </h4>
# 1.	AES
# 2.	Ceasar
# 3.	Playfair
# 4.	Vigenere
# 5.  Autokey
# 6.  Railfence
#
#
# <h4>Technologies: </h4>
# 1.	Python.
# 2.  pycipher.
#
# <h4>Install: </h4>
# 1.	Python3.
# 2.  Anaconda.
# 3.  pycipher (pip install pycipher)

# %%
Sbox = (
            
            )

# %%
def letterstohex(message):
    hex_coded = message.encode('utf-8')
    hex_coded = hex_coded.hex()
    n = 2
    hex_coded=[hex_coded[i:i+n] for i in range(0, len(hex_coded), n)]
    return hex_coded

# %%
#A function to divide the message into 128 bits, and fill the last part
#with zero paddings.
def split_string(message):
    
    arr_message = []
    
    while message:
        
        if len(message)<16:
            message = format(message, '16')
            arr_message.append(message)
            break
        else:
            arr_message.append(message[:16])
            if len(message)>16:
                message = message[16:]  
            elif len(message)==16:
                break
              
    return arr_message

# %%
def format_arr_hex(arr_message):
    
    arr_hex = []
    
    for i in range(0, len(arr_message)):
        
        arr_hex.append(letterstohex(arr_message[i]))
        
    return arr_hex

# %%
import copy

def RoundKeys(key):
    
    RoundKeys = []
    rc= ['1', '2', '4', '8', '10', '20', '40', '80', '1b', '36']
    RoundKeys.append(key)
    
    for i in range(0, 10):
        
        k_1st = key[:4]
        k_2nd = key[4:8]
        k_3rd = key[8:12]
        k_4th = key[12:16]
        
        g_k_4th = copy.deepcopy(k_4th)

        g_k_4th = [g_k_4th[1], g_k_4th[2], g_k_4th[3], g_k_4th[0]]
        
        for m in range(0, 4):
            g_k_4th[m][0] = format(Sbox[sbox_number(g_k_4th[m][0])], '02x')
           
        
        result = hex(int(g_k_4th[0][0], 16) ^ int(rc[i], 16))
        #rc *= 2
        test = str(result[2:])
        if len(test) < 2:
            test = '0' + test
        g_k_4th[0][0] = test
        k_5th = xor_hex(k_1st, g_k_4th)
        k_6th = xor_hex(k_5th, k_2nd)
        k_7th = xor_hex(k_6th, k_3rd)
        k_8th = xor_hex(k_7th, k_4th)
        rk = [k_5th[0], k_5th[1], k_5th[2], k_5th[3], k_6th[0], k_6th[1], k_6th[2], k_6th[3], k_7th[0], k_7th[1], k_7th[2], k_7th[3], k_8th[0], k_8th[1], k_8th[2], k_8th[3]] 
        
        for ra in range(0, len(rk)):
            if len(rk[ra][0])<2:
                rk[ra][0] = '0' + rk[ra][0]  
        
        RoundKeys.append(rk)
        key = copy.deepcopy(rk)
        
    return RoundKeys

# %%
def xor_hex(arr_str1, arr_str2):
    
    result0 = hex(int(arr_str1[0][0], 16) ^ int(arr_str2[0][0], 16))
    result1 = hex(int(arr_str1[1][0], 16) ^ int(arr_str2[1][0], 16))
    result2 = hex(int(arr_str1[2][0], 16) ^ int(arr_str2[2][0], 16))
    result3 = hex(int(arr_str1[3][0], 16) ^ int(arr_str2[3][0], 16))
    
    ret = [[str(result0[2:])], [str(result1[2:])], [str(result2[2:])], [str(result3[2:])]]
    return ret

# %%
def sbox_number(stringx):
    
    if len(stringx) < 2:
        
         stringx = '0' + stringx
            
    sp = list(stringx)
    
    sbox_number_1 = 0
    sbox_number_2 = 0
    
    if sp[0]=='0' or sp[0]=='1' or sp[0]=='2' or sp[0]=='3' or sp[0]=='4' or sp[0]=='5' or sp[0]=='6' or sp[0]=='7' or sp[0]=='8' or sp[0]=='9':
        sbox_number_1 = int(sp[0])
        
    elif sp[0] == 'a':
        sbox_number_1 = 10
        
    elif sp[0] == 'b':
        sbox_number_1 = 11
        
    elif sp[0] == 'c':
        sbox_number_1 = 12
        
    elif sp[0] == 'd':
        sbox_number_1 = 13
        
    elif sp[0] == 'e':
        sbox_number_1 = 14
        
    elif sp[0] == 'f':
        sbox_number_1 = 15
        
    if sp[1]=='0' or sp[1]=='1' or sp[1]=='2' or sp[1]=='3' or sp[1]=='4' or sp[1]=='5' or sp[1]=='6' or sp[1]=='7' or sp[1]=='8' or sp[1]=='9':
        sbox_number_2 = int(sp[1])
        
    elif sp[1] == 'a':
        sbox_number_2 = 10
        
    elif sp[1] == 'b':
        sbox_number_2 = 11
        
    elif sp[1] == 'c':
        sbox_number_2 = 12
        
    elif sp[1] == 'd':
        sbox_number_2 = 13
        
    elif sp[1] == 'e':
        sbox_number_2 = 14
        
    elif sp[1] == 'f':
        sbox_number_2 = 15
    
    return sbox_number_1 * 16 + sbox_number_2

# %%
def AddRoundKey(message,key):
    
    result0 = hex(int(message[0][0], 16) ^ int(key[0][0], 16))
    result1 = hex(int(message[1][0], 16) ^ int(key[1][0], 16))
    result2 = hex(int(message[2][0], 16) ^ int(key[2][0], 16))
    result3 = hex(int(message[3][0], 16) ^ int(key[3][0], 16))
    result4 = hex(int(message[4][0], 16) ^ int(key[4][0], 16))
    result5 = hex(int(message[5][0], 16) ^ int(key[5][0], 16))
    result6 = hex(int(message[6][0], 16) ^ int(key[6][0], 16))
    result7 = hex(int(message[7][0], 16) ^ int(key[7][0], 16))
    result8 = hex(int(message[8][0], 16) ^ int(key[8][0], 16))
    result9 = hex(int(message[9][0], 16) ^ int(key[9][0], 16))
    result1m = hex(int(message[10][0], 16) ^ int(key[10][0], 16))
    result2m = hex(int(message[11][0], 16) ^ int(key[11][0], 16))
    result3m = hex(int(message[12][0], 16) ^ int(key[12][0], 16))
    result4m = hex(int(message[13][0], 16) ^ int(key[13][0], 16))
    result5m = hex(int(message[14][0], 16) ^ int(key[14][0], 16))
    result6m = hex(int(message[15][0], 16) ^ int(key[15][0], 16))
    ret = [[str(result0[2:])], [str(result1[2:])], [str(result2[2:])], 
           [str(result3[2:])], [str(result4[2:])], [str(result5[2:])], 
           [str(result6[2:])], [str(result7[2:])], [str(result8[2:])], 
           [str(result9[2:])], [str(result1m[2:])], [str(result2m[2:])], 
           [str(result3m[2:])], [str(result4m[2:])], [str(result5m[2:])], 
           [str(result6m[2:])]]
           
           
    return ret

# %%
def shiftRows(single_state):
    
    rows = []
    for i in range(0, 4):
        for j in range(i, 16, 4):
            rows.append(single_state[j][0])
    
    r0 = rows[0:4]
    r1 = rows[4:8]
    r2 = rows[8:12]
    r3 = rows[12:16]
    
    r0 = [[r0[0]], [r0[1]], [r0[2]], [r0[3]]]
    r1 = [[r1[1]], [r1[2]], [r1[3]], [r1[0]]]
    r2 = [[r2[2]], [r2[3]], [r2[0]], [r2[1]]]
    r3 = [[r3[3]], [r3[0]], [r3[1]], [r3[2]]]
    
    
    shifted_rows = r0 + r1 + r2 + r3
    
    rows_back = []
    
    for i in range(0, 4):
        for j in range(i, 16, 4):
            rows_back.append(shifted_rows[j][0])
            
    r0_back = rows_back[0:4]
    r1_back = rows_back[4:8]
    r2_back = rows_back[8:12]
    r3_back = rows_back[12:16]
    
    r0_back = [[r0_back[0]], [r0_back[1]], [r0_back[2]], [r0_back[3]]]
    r1_back = [[r1_back[0]], [r1_back[1]], [r1_back[2]], [r1_back[3]]]
    r2_back = [[r2_back[0]], [r2_back[1]], [r2_back[2]], [r2_back[3]]]
    r3_back = [[r3_back[0]], [r3_back[1]], [r3_back[2]], [r3_back[3]]]
    
    shifted_rows_back = r0_back + r1_back + r2_back + r3_back
            
    return shifted_rows_back

# %%
def galois_mult(a, b):
   
    p = 0
    hi_bit_set = 0
    for i in range(8):
        if b & 1 == 1: p ^= a
        hi_bit_set = a & 0x80
        a <<= 1
        if hi_bit_set == 0x80: a ^= 0x1b
        b >>= 1
    return p % 256

# %%
def MixColumns(state):
    
    mixed = []
    
    fixed = [['02'], ['03'], ['01'], 
             ['01'], ['01'], ['02'], 
             ['03'], ['01'], ['01'], 
             ['01'], ['02'], ['03'], 
             ['03'], ['01'], ['01'], 
             ['02']]
    
    final0 = hex(galois_mult(int(fixed[0][0],16), int(state[0][0],16))
                 ^galois_mult(int(fixed[1][0],16), int(state[1][0],16))
                 ^galois_mult(int(fixed[2][0],16), int(state[2][0],16))
                 ^galois_mult(int(fixed[3][0],16), int(state[3][0],16)))

    final1 = hex(galois_mult(int(fixed[4][0],16), int(state[0][0],16))
                 ^galois_mult(int(fixed[5][0],16), int(state[1][0],16))
                 ^galois_mult(int(fixed[6][0],16), int(state[2][0],16))
                 ^galois_mult(int(fixed[7][0],16), int(state[3][0],16)))
    
    final2 = hex(galois_mult(int(fixed[8][0],16), int(state[0][0],16))
                 ^galois_mult(int(fixed[9][0],16), int(state[1][0],16))
                 ^galois_mult(int(fixed[10][0],16), int(state[2][0],16))
                 ^galois_mult(int(fixed[11][0],16), int(state[3][0],16)))
    
    final3 = hex(galois_mult(int(fixed[12][0],16), int(state[0][0],16))
                 ^galois_mult(int(fixed[13][0],16), int(state[1][0],16))
                 ^galois_mult(int(fixed[14][0],16), int(state[2][0],16))
                 ^galois_mult(int(fixed[15][0],16), int(state[3][0],16)))
    
    final4 = hex(galois_mult(int(fixed[0][0],16), int(state[4][0],16))
                 ^galois_mult(int(fixed[1][0],16), int(state[5][0],16))
                 ^galois_mult(int(fixed[2][0],16), int(state[6][0],16))
                 ^galois_mult(int(fixed[3][0],16), int(state[7][0],16)))
    
    final5 = hex(galois_mult(int(fixed[4][0],16), int(state[4][0],16))
                 ^galois_mult(int(fixed[5][0],16), int(state[5][0],16))
                 ^galois_mult(int(fixed[6][0],16), int(state[6][0],16))
                 ^galois_mult(int(fixed[7][0],16), int(state[7][0],16)))
    
    final6 = hex(galois_mult(int(fixed[8][0],16), int(state[4][0],16))
                 ^galois_mult(int(fixed[9][0],16), int(state[5][0],16))
                 ^galois_mult(int(fixed[10][0],16), int(state[6][0],16))
                 ^galois_mult(int(fixed[11][0],16), int(state[7][0],16)))
    
    final7 = hex(galois_mult(int(fixed[12][0],16), int(state[4][0],16))
                 ^galois_mult(int(fixed[13][0],16), int(state[5][0],16))
                 ^galois_mult(int(fixed[14][0],16), int(state[6][0],16))
                 ^galois_mult(int(fixed[15][0],16), int(state[7][0],16)))
    
    final8 = hex(galois_mult(int(fixed[0][0],16), int(state[8][0],16))
                 ^galois_mult(int(fixed[1][0],16), int(state[9][0],16))
                 ^galois_mult(int(fixed[2][0],16), int(state[10][0],16))
                 ^galois_mult(int(fixed[3][0],16), int(state[11][0],16)))
    
    final9 = hex(galois_mult(int(fixed[4][0],16), int(state[8][0],16))
                 ^galois_mult(int(fixed[5][0],16), int(state[9][0],16))
                 ^galois_mult(int(fixed[6][0],16), int(state[10][0],16))
                 ^galois_mult(int(fixed[7][0],16), int(state[11][0],16)))
    
    final10 = hex(galois_mult(int(fixed[8][0],16), int(state[8][0],16))
                  ^galois_mult(int(fixed[9][0],16), int(state[9][0],16))
                  ^galois_mult(int(fixed[10][0],16), int(state[10][0],16))
                  ^galois_mult(int(fixed[11][0],16), int(state[11][0],16)))
    
    final11 = hex(galois_mult(int(fixed[12][0],16), int(state[8][0],16))
                  ^galois_mult(int(fixed[13][0],16), int(state[9][0],16))
                  ^galois_mult(int(fixed[14][0],16), int(state[10][0],16))
                  ^galois_mult(int(fixed[15][0],16), int(state[11][0],16)))
    
    final12 = hex(galois_mult(int(fixed[0][0],16), int(state[12][0],16))
                  ^galois_mult(int(fixed[1][0],16), int(state[13][0],16))
                  ^galois_mult(int(fixed[2][0],16), int(state[14][0],16))
                  ^galois_mult(int(fixed[3][0],16), int(state[15][0],16)))
    
    final13 = hex(galois_mult(int(fixed[4][0],16), int(state[12][0],16))
                  ^galois_mult(int(fixed[5][0],16), int(state[13][0],16))
                  ^galois_mult(int(fixed[6][0],16), int(state[14][0],16))
                  ^galois_mult(int(fixed[7][0],16), int(state[15][0],16)))
    
    final14 = hex(galois_mult(int(fixed[8][0],16), int(state[12][0],16))
                  ^galois_mult(int(fixed[9][0],16), int(state[13][0],16))
                  ^galois_mult(int(fixed[10][0],16), int(state[14][0],16))
                  ^galois_mult(int(fixed[11][0],16), int(state[15][0],16)))
    
    final15 = hex(galois_mult(int(fixed[12][0],16), int(state[12][0],16))
                  ^galois_mult(int(fixed[13][0],16), int(state[13][0],16))
                  ^galois_mult(int(fixed[14][0],16), int(state[14][0],16))
                  ^galois_mult(int(fixed[15][0],16), int(state[15][0],16)))
    
    mixed = [[final0[2:]], [final1[2:]], [final2[2:]], [final3[2:]], [final4[2:]],
             [final5[2:]], [final6[2:]], [final7[2:]], [final8[2:]], [final9[2:]], 
             [final10[2:]], [final11[2:]], [final12[2:]], [final13[2:]], [final14[2:]], 
             [final15[2:]]]
    
    return mixed

# %%
def aes_encrypt(message, key):
    arr_message = split_string(message)
    arr_hex_message = []
    for i in range(0, len(arr_message)):
        arr_hex_message.append(format_arr_hex(arr_message[i]))
    
    print("")
    print("")
    print("SHOWING VARIABLES: ")
    print("")
    print("")
    arr_hex_key = format_arr_hex(key)
    print('The key in the hexadecimal is: ', arr_hex_key)
    print("")
    
    for i in range(0, len(arr_hex_message)):
        
        print('The message in the hexadecimal of the word',str(i+1),' is: ', arr_hex_message[i])
        print("")
        
    RK = RoundKeys(arr_hex_key)
    
    print("")
    print("")
    print("ROUNDKEYS: ")
    print("")
    print("")
    for i in range(0, len(RK)):
        print('RoundKey number ',str((i)),': ',RK[i])
        print("")
            
    
    #initialRound
    
    print("")
    print("")
    print("##### START OF ROUND 0: ######")
    print("")
    print("")
    
    #Add_Round_Key
    
    add_rk_init = []
    print("")
    print("")
    print("ADDING Initial ROUNDKEY: ")
    print("")
    print("")
    for i in range(0, len(arr_hex_message)):
        
        add_single_rk = AddRoundKey(arr_hex_message[i],RK[0])   
        print('The state of message',str(i+1),' after adding roundkey number ',str(0),' is: ', add_single_rk)
        print("")
        add_rk_init.append(add_single_rk)
    
    
    print("")
    print("")
    print("##### END OF ROUND 0: ######")
    print("")
    print("")
      
    
    final_iter = []
    final_iter.append(add_rk_init)
    
    for iterfinal in range(0, len(RK)-2):
        
        print("")
        print("")
        print("##### START OF ROUND ",str(iterfinal+1),": ######")
        print("")
        print("")

        #Substitution_Bytes
        subs_bytes = []

        for i in range(0, len(final_iter[iterfinal])):

            for j in range(0, len(final_iter[iterfinal][i])):

                final_iter[iterfinal][i][j][0] = format(Sbox[sbox_number(final_iter[iterfinal][i][j][0])], '02x')

            subs_bytes.append(final_iter[iterfinal][i])

        print("")
        print("")
        print("SUBSTITUTION: ")
        print("")
        print("")

        for i in range(0, len(subs_bytes)):

            print('The state of message',str(i+1),' after substitution is: ', subs_bytes[i])
            print("")

        #ShiftRows
        shifted_rows = []
        for i in range(0, len(subs_bytes)):
            shifted_rows.append(shiftRows(subs_bytes[i]))

        print("")
        print("")
        print("SHIFT ROWS: ")
        print("")
        print("")

        for i in range(0, len(shifted_rows)):

            print('The state of message',str(i+1),' after shifting rows is: ', shifted_rows[i])
            print("")

        print("")
        print("")
        print("MIX COLUMNS: ")
        print("")
        print("")    

        mixed_columns = []
        for i in range(0, len(shifted_rows)):
            mixed_columns.append(MixColumns(shifted_rows[i]))

        for i in range(0, len(mixed_columns)):

            print('The state of message',str(i+1),' after mixing columns is: ', mixed_columns[i])
            print("")


        print("")
        print("")
        print("Add Round Keys: ")
        print("")
        print("") 

        add_rk = []

        for i in range(0, len(arr_hex_message)):

            add_single_rk = AddRoundKey(mixed_columns[i],RK[iterfinal+1])   
            print('The state of message',str(i+1),' after adding roundkey is: ', add_single_rk)
            print("")
            add_rk.append(add_single_rk)

        final_iter.append(add_rk)
        
        print("")
        print("")
        print("##### END OF ROUND ",str(iterfinal+1),": ######")
        print("")
        print("")
        
    print("")
    print("")
    print("##### START OF FINAL ROUND : ######")
    print("")
    print("")

    #Substitution_Bytes
    subs_bytes = []

    for i in range(0, len(final_iter[-1])):

        for j in range(0, len(final_iter[-1][i])):

            final_iter[-1][i][j][0] = format(Sbox[sbox_number(final_iter[-1][i][j][0])], '02x')

        subs_bytes.append(final_iter[-1][i])

    print("")
    print("")
    print("SUBSTITUTION: ")
    print("")
    print("")

    for i in range(0, len(subs_bytes)):

        print('The state of message',str(i+1),' after substitution is: ', subs_bytes[i])
        print("")

    #ShiftRows
    shifted_rows = []
    for i in range(0, len(subs_bytes)):
        shifted_rows.append(shiftRows(subs_bytes[i]))

    print("")
    print("")
    print("SHIFT ROWS: ")
    print("")
    print("")

    for i in range(0, len(shifted_rows)):

        print('The state of message',str(i+1),' after shifting rows is: ', shifted_rows[i])
        print("")


    print("")
    print("")
    print("Add Round Keys: ")
    print("")
    print("") 

    add_rk = []

    for i in range(0, len(arr_hex_message)):

        add_single_rk = AddRoundKey(shifted_rows[i],RK[-1])   
        print('The state of message',str(i+1),' after adding roundkey is: ', add_single_rk)
        print("")
        add_rk.append(add_single_rk)
    
    final = ''
    for i in range(0, len(add_rk)):
        for j in range(0, len(add_rk[i])):
            final += add_rk[i][j][0]
    print('The ENCRYPTION is:', final)     
    return final
    print("")
    print("")
    
    print("")
    print("")
    print("##### END OF FINAL ROUND ######")
    print("")
    print("")

# %%
from tkinter import *
from tkinter import messagebox
from pycipher import Caesar
from pycipher import Playfair
from pycipher import Vigenere
from pycipher import Autokey
from pycipher import Railfence

#put encryption code inside here:
def Encrypt_AES():
    
    inputMessage = inputBox.get()
    Key = inputKeyBox.get()
    
    inputMessage = ""
    key = ""
    finalMessage=""
    output.delete('1.0', END)
    inputMessage = inputBox.get()
    Key = inputKeyBox.get()
    
    if inputMessage == "" or Key == "":
        messagebox.showinfo('Input Error','You must enter both key and message')
    elif len(Key) != 16:
        messagebox.showinfo('Input Error','In AES Key must be 16 characters')
    else:
        finalMessage = aes_encrypt(inputMessage, Key)
        
    output.insert(END, finalMessage) #replace inputMessage with final result
    print("Done")  
    output.insert(END, finalMessage) #replace inputMessage with final result
    print("Done")

    
def Encrypt_Ceasar():
    
    inputMessage = inputBox.get()
    Key = inputKeyBox.get()
    finalMessage=""
    output.delete('1.0', END)
    try:
           finalMessage = Caesar(key=int(Key)).encipher(inputMessage)
    except ValueError:
            messagebox.showinfo('Enter an integer','In ceasar cipher you must enter an integer')
    
    
    output.insert(END, finalMessage) #replace inputMessage with final result
    print("Done")    
    

def Encrypt_Playfair():
    
    inputMessage = ""
    key = ""
    finalMessage=""
    output.delete('1.0', END) 
    inputMessage = inputBox.get()
    Key = inputKeyBox.get()
    
    
    if inputMessage == "" or Key == "":
        messagebox.showinfo('Input Error','You must enter both key and message')
    else:
        if len(set(Key)) == len(Key) and len(Key)==25:
            finalMessage = Playfair(Key).encipher(inputMessage)
        else:
            messagebox.showinfo('Input Error','For playcipher, the key must be 25 different letters')
        
    output.insert(END, finalMessage) #replace inputMessage with final result
    print("Done")  
    
    
def Encrypt_Vingenere():
    
    inputMessage = ""
    key = ""
    finalMessage=""
    output.delete('1.0', END)
    inputMessage = inputBox.get()
    Key = inputKeyBox.get()
    
    
    if inputMessage == "" or Key == "":
        messagebox.showinfo('Input Error','You must enter both key and message')
    else:
        finalMessage = Vigenere(Key).encipher(inputMessage)
        
    output.insert(END, finalMessage) #replace inputMessage with final result
    print("Done")  
    
    output.insert(END, finalMessage) #replace inputMessage with final result
    print("Done")  

def Encrypt_AutoKey():
    inputMessage = ""
    key = ""
    finalMessage=""
    output.delete('1.0', END)
    inputMessage = inputBox.get()
    Key = inputKeyBox.get()
    
    
    if inputMessage == "" or Key == "":
        messagebox.showinfo('Input Error','You must enter both key and message')
    else:
        finalMessage = Autokey(Key).encipher(inputMessage)
        
    output.insert(END, finalMessage) #replace inputMessage with final result
    print("Done")  
    
    output.insert(END, finalMessage) #replace inputMessage with final result
    print("Done")  
 

def Encrypt_RealFence():
    
    inputMessage = inputBox.get()
    Key = inputKeyBox.get()
    finalMessage=""
    output.delete('1.0', END)
    try:
           finalMessage = Railfence(key=int(Key)).encipher(inputMessage)
    except ValueError:
            messagebox.showinfo('Enter an integer','In ceasar cipher you must enter an integer')
    
    
    output.insert(END, finalMessage) #replace inputMessage with final result
    print("Done")

    
#Initiating GUI
rootframe=Tk()

#title and size of frame
rootframe.title("Security Project")
rootframe.geometry("800x400")
rootframe.configure(background='#a3e6c6')

#items in the frame

#Message input in row 0
a = Label(rootframe, text="Message ", font=16)
a.config(font=("Courier", 16))
a.grid(row=0,column=0,sticky=W)

inputBox = Entry(rootframe, width=50, bg="white")
inputBox.grid(row=0, column=1, sticky=W)

#Key input in row 1
b = Label(rootframe, text="Key", font=16)
b.config(font=("Courier", 16))
b.grid(row=1,column=0,sticky=W)
inputKeyBox = Entry(rootframe, width=50, bg="white")
inputKeyBox.grid(row=1, column=1, sticky=W)


#button in row 2
AES_button = Button(rootframe, text="AES Encryption", width=16, command=Encrypt_AES, bg='#abeaa7', fg='black')
AES_button.grid(row=2,column=0,sticky=W, padx=0, pady=10)

Ceasar_button = Button(rootframe, text="Ceasar Encryption", width=16, command=Encrypt_Ceasar, bg='#abeaa7', fg='black')
Ceasar_button.grid(row=2,column=1,sticky=W, padx=5, pady=10)

Playfair_button = Button(rootframe, text="Playfair Encryption", width=16, command=Encrypt_Playfair, bg='#abeaa7', fg='black')
Playfair_button.grid(row=3,column=0,sticky=W, padx=0, pady=10)

vingenere_button = Button(rootframe, text="Vingenere Encryption", width=16, command=Encrypt_Vingenere, bg='#abeaa7', fg='black')
vingenere_button.grid(row=3,column=1,sticky=W, padx=5, pady=10)

autokey_button = Button(rootframe, text="AutoKey Encryption", width=16, command=Encrypt_AutoKey, bg='#abeaa7', fg='black')
autokey_button.grid(row=4,column=0,sticky=W, padx=0, pady=10)

realfence_button = Button(rootframe, text="RealFence Encryption", width=16, command=Encrypt_RealFence, bg='#abeaa7', fg='black')
realfence_button.grid(row=4,column=1,sticky=W, padx=5, pady=10)


#output in row 3
label = Label(rootframe, text="Cyphertext")
label.config(font=("Courier", 25))
label.grid(row=5,column=0, sticky=W, pady=30)
output = Text(rootframe, width=50, height=5, background="#f5c1b3")
output.grid(row=5, column=1, sticky=W, padx = 10, pady=50)

#this keeps the frame running, any part of the frame should be added before it
rootframe.mainloop()
# Out:
# SHOWING VARIABLES:
#
#
# The key in the hexadecimal is:  [['54'], ['68'], ['61'], ['74'], ['73'], ['20'], ['6d'], ['79'], ['20'], ['4b'], ['75'], ['6e'], ['67'], ['20'], ['46'], ['75']]
#
# The message in the hexadecimal of the word 1  is:  [['54'], ['77'], ['6f'], ['20'], ['4f'], ['6e'], ['65'], ['20'], ['4e'], ['69'], ['6e'], ['65'], ['20'], ['54'], ['77'], ['6f']]
#
# The message in the hexadecimal of the word 2  is:  [['20'], ['54'], ['68'], ['61'], ['74'], ['73'], ['20'], ['6d'], ['79'], ['20'], ['4b'], ['75'], ['6e'], ['67'], ['20'], ['46']]
#
# The message in the hexadecimal of the word 3  is:  [['75'], ['20'], ['62'], ['75'], ['74'], ['20'], ['77'], ['65'], ['20'], ['63'], ['61'], ['6e'], ['74'], ['20'], ['6b'], ['6e']]
#
# The message in the hexadecimal of the word 4  is:  [['6f'], ['77'], ['20'], ['66'], ['6f'], ['72'], ['20'], ['73'], ['75'], ['72'], ['65'], ['20'], ['77'], ['65'], ['20'], ['77']]
#
# The message in the hexadecimal of the word 5  is:  [['69'], ['6c'], ['6c'], ['20'], ['68'], ['6f'], ['70'], ['65'], ['20'], ['20'], ['20'], ['20'], ['20'], ['20'], ['20'], ['20']]
#
#
#
# ROUNDKEYS:
#
#
# RoundKey number  0 :  [['54'], ['68'], ['61'], ['74'], ['73'], ['20'], ['6d'], ['79'], ['20'], ['4b'], ['75'], ['6e'], ['67'], ['20'], ['46'], ['75']]
#
# RoundKey number  1 :  [['e2'], ['32'], ['fc'], ['f1'], ['91'], ['12'], ['91'], ['88'], ['b1'], ['59'], ['e4'], ['e6'], ['d6'], ['79'], ['a2'], ['93']]
#
# RoundKey number  2 :  [['56'], ['08'], ['20'], ['07'], ['c7'], ['1a'], ['b1'], ['8f'], ['76'], ['43'], ['55'], ['69'], ['a0'], ['3a'], ['f7'], ['fa']]
#
# RoundKey number  3 :  [['d2'], ['60'], ['0d'], ['e7'], ['15'], ['7a'], ['bc'], ['68'], ['63'], ['39'], ['e9'], ['01'], ['c3'], ['03'], ['1e'], ['fb']]
#
# RoundKey number  4 :  [['a1'], ['12'], ['02'], ['c9'], ['b4'], ['68'], ['be'], ['a1'], ['d7'], ['51'], ['57'], ['a0'], ['14'], ['52'], ['49'], ['5b']]
#
# RoundKey number  5 :  [['b1'], ['29'], ['3b'], ['33'], ['05'], ['41'], ['85'], ['92'], ['d2'], ['10'], ['d2'], ['32'], ['c6'], ['42'], ['9b'], ['69']]
#
# RoundKey number  6 :  [['bd'], ['3d'], ['c2'], ['87'], ['b8'], ['7c'], ['47'], ['15'], ['6a'], ['6c'], ['95'], ['27'], ['ac'], ['2e'], ['0e'], ['4e']]
#
# RoundKey number  7 :  [['cc'], ['96'], ['ed'], ['16'], ['74'], ['ea'], ['aa'], ['03'], ['1e'], ['86'], ['3f'], ['24'], ['b2'], ['a8'], ['31'], ['6a']]
#
# RoundKey number  8 :  [['8e'], ['51'], ['ef'], ['21'], ['fa'], ['bb'], ['45'], ['22'], ['e4'], ['3d'], ['7a'], ['06'], ['56'], ['95'], ['4b'], ['6c']]
#
# RoundKey number  9 :  [['bf'], ['e2'], ['bf'], ['90'], ['45'], ['59'], ['fa'], ['b2'], ['a1'], ['64'], ['80'], ['b4'], ['f7'], ['f1'], ['cb'], ['d8']]
#
# RoundKey number  10 :  [['28'], ['fd'], ['de'], ['f8'], ['6d'], ['a4'], ['24'], ['4a'], ['cc'], ['c0'], ['a4'], ['fe'], ['3b'], ['31'], ['6f'], ['26']]
#
#
#
# ##### START OF ROUND 0: ######
#
#
#
#
# ADDING Initial ROUNDKEY:
#
#
# The state of message 1  after adding roundkey number  0  is:  [['0'], ['1f'], ['e'], ['54'], ['3c'], ['4e'], ['8'], ['59'], ['6e'], ['22'], ['1b'], ['b'], ['47'], ['74'], ['31'], ['1a']]
#
# The state of message 2  after adding roundkey number  0  is:  [['74'], ['3c'], ['9'], ['15'], ['7'], ['53'], ['4d'], ['14'], ['59'], ['6b'], ['3e'], ['1b'], ['9'], ['47'], ['66'], ['33']]
#
# The state of message 3  after adding roundkey number  0  is:  [['21'], ['48'], ['3'], ['1'], ['7'], ['0'], ['1a'], ['1c'], ['0'], ['28'], ['14'], ['0'], ['13'], ['0'], ['2d'], ['1b']]
#
# The state of message 4  after adding roundkey number  0  is:  [['3b'], ['1f'], ['41'], ['12'], ['1c'], ['52'], ['4d'], ['a'], ['55'], ['39'], ['10'], ['4e'], ['10'], ['45'], ['66'], ['2']]
#
# The state of message 5  after adding roundkey number  0  is:  [['3d'], ['4'], ['d'], ['54'], ['1b'], ['4f'], ['1d'], ['1c'], ['0'], ['6b'], ['55'], ['4e'], ['47'], ['0'], ['66'], ['55']]
#
#
#
# ##### END OF ROUND 0: ######
#
#
#
#
# ##### START OF ROUND  1 : ######
#
#
#
#
# SUBSTITUTION:
#
#
# The state of message 1  after substitution is:  [['63'], ['c0'], ['ab'], ['20'], ['eb'], ['2f'], ['30'], ['cb'], ['9f'], ['93'], ['af'], ['2b'], ['a0'], ['92'], ['c7'], ['a2']]
#
# The state of message 2  after substitution is:  [['92'], ['eb'], ['01'], ['59'], ['c5'], ['ed'], ['e3'], ['fa'], ['cb'], ['7f'], ['b2'], ['af'], ['01'], ['a0'], ['33'], ['c3']]
#
# The state of message 3  after substitution is:  [['fd'], ['52'], ['7b'], ['7c'], ['c5'], ['63'], ['a2'], ['9c'], ['63'], ['34'], ['fa'], ['63'], ['7d'], ['63'], ['d8'], ['af']]
#
# The state of message 4  after substitution is:  [['e2'], ['c0'], ['83'], ['c9'], ['9c'], ['00'], ['e3'], ['67'], ['fc'], ['12'], ['ca'], ['2f'], ['ca'], ['6e'], ['33'], ['77']]
#
# The state of message 5  after substitution is:  [['27'], ['f2'], ['d7'], ['20'], ['af'], ['84'], ['a4'], ['9c'], ['63'], ['7f'], ['fc'], ['2f'], ['a0'], ['63'], ['33'], ['fc']]
#
#
#
# SHIFT ROWS:
#
#
# The state of message 1  after shifting rows is:  [['63'], ['2f'], ['af'], ['a2'], ['eb'], ['93'], ['c7'], ['20'], ['9f'], ['92'], ['ab'], ['cb'], ['a0'], ['c0'], ['30'], ['2b']]
#
# The state of message 2  after shifting rows is:  [['92'], ['ed'], ['b2'], ['c3'], ['c5'], ['7f'], ['33'], ['59'], ['cb'], ['a0'], ['01'], ['fa'], ['01'], ['eb'], ['e3'], ['af']]
#
# The state of message 3  after shifting rows is:  [['fd'], ['63'], ['fa'], ['af'], ['c5'], ['34'], ['d8'], ['7c'], ['63'], ['63'], ['7b'], ['9c'], ['7d'], ['52'], ['a2'], ['63']]
#
# The state of message 4  after shifting rows is:  [['e2'], ['00'], ['ca'], ['77'], ['9c'], ['12'], ['33'], ['c9'], ['fc'], ['6e'], ['83'], ['67'], ['ca'], ['c0'], ['e3'], ['2f']]
#
# The state of message 5  after shifting rows is:  [['27'], ['84'], ['fc'], ['fc'], ['af'], ['7f'], ['33'], ['20'], ['63'], ['63'], ['d7'], ['9c'], ['a0'], ['f2'], ['a4'], ['2f']]
#
#
#
# MIX COLUMNS:
#
#
# The state of message 1  after mixing columns is:  [['ba'], ['75'], ['f4'], ['7a'], ['84'], ['a4'], ['8d'], ['32'], ['e8'], ['8d'], ['6'], ['e'], ['1b'], ['40'], ['7d'], ['5d']]
#
# The state of message 2  after mixing columns is:  [['62'], ['5d'], ['5e'], ['6f'], ['7a'], ['37'], ['37'], ['aa'], ['8d'], ['69'], ['7c'], ['8'], ['68'], ['5d'], ['dd'], ['4e']]
#
# The state of message 3  after mixing columns is:  [['11'], ['81'], ['9b'], ['c0'], ['69'], ['a2'], ['de'], ['40'], ['84'], ['b4'], ['49'], ['9e'], ['cd'], ['47'], ['d5'], ['b1']]
#
# The state of message 4  after mixing columns is:  [['62'], ['d0'], ['f4'], ['19'], ['ef'], ['24'], ['a8'], ['17'], ['b5'], ['d9'], ['26'], ['3c'], ['18'], ['40'], ['a6'], ['38']]
#
# The state of message 5  after mixing columns is:  [['d9'], ['d7'], ['5f'], ['f2'], ['d7'], ['24'], ['d6'], ['e6'], ['28'], ['5b'], ['a'], ['32'], ['dd'], ['87'], ['70'], ['f3']]
#
#
#
# Add Round Keys:
#
#
# The state of message 1  after adding roundkey is:  [['58'], ['47'], ['8'], ['8b'], ['15'], ['b6'], ['1c'], ['ba'], ['59'], ['d4'], ['e2'], ['e8'], ['cd'], ['39'], ['df'], ['ce']]
#
# The state of message 2  after adding roundkey is:  [['80'], ['6f'], ['a2'], ['9e'], ['eb'], ['25'], ['a6'], ['22'], ['3c'], ['30'], ['98'], ['ee'], ['be'], ['24'], ['7f'], ['dd']]
#
# The state of message 3  after adding roundkey is:  [['f3'], ['b3'], ['67'], ['31'], ['f8'], ['b0'], ['4f'], ['c8'], ['35'], ['ed'], ['ad'], ['78'], ['1b'], ['3e'], ['77'], ['22']]
#
# The state of message 4  after adding roundkey is:  [['80'], ['e2'], ['8'], ['e8'], ['7e'], ['36'], ['39'], ['9f'], ['4'], ['80'], ['c2'], ['da'], ['ce'], ['39'], ['4'], ['ab']]
#
# The state of message 5  after adding roundkey is:  [['3b'], ['e5'], ['a3'], ['3'], ['46'], ['36'], ['47'], ['6e'], ['99'], ['2'], ['ee'], ['d4'], ['b'], ['fe'], ['d2'], ['60']]
#
#
#
# ##### END OF ROUND  1 : ######
#
#
#
#
# ##### START OF ROUND  2 : ######
#
#
#
#
# SUBSTITUTION:
#
#
# The state of message 1  after substitution is:  [['6a'], ['a0'], ['30'], ['3d'], ['59'], ['4e'], ['9c'], ['f4'], ['cb'], ['48'], ['98'], ['9b'], ['bd'], ['12'], ['9e'], ['8b']]
#
# The state of message 2  after substitution is:  [['cd'], ['a8'], ['3a'], ['0b'], ['e9'], ['3f'], ['24'], ['93'], ['eb'], ['04'], ['46'], ['28'], ['ae'], ['36'], ['d2'], ['c1']]
#
# The state of message 3  after substitution is:  [['0d'], ['6d'], ['85'], ['c7'], ['41'], ['e7'], ['84'], ['e8'], ['96'], ['55'], ['95'], ['bc'], ['af'], ['b2'], ['f5'], ['93']]
#
# The state of message 4  after substitution is:  [['cd'], ['98'], ['30'], ['9b'], ['f3'], ['05'], ['12'], ['db'], ['f2'], ['cd'], ['25'], ['57'], ['8b'], ['12'], ['f2'], ['62']]
#
# The state of message 5  after substitution is:  [['e2'], ['d9'], ['0a'], ['7b'], ['5a'], ['05'], ['a0'], ['9f'], ['ee'], ['77'], ['28'], ['48'], ['2b'], ['bb'], ['b5'], ['d0']]
#
#
#
# SHIFT ROWS:
#
#
# The state of message 1  after shifting rows is:  [['6a'], ['4e'], ['98'], ['8b'], ['59'], ['48'], ['9e'], ['3d'], ['cb'], ['12'], ['30'], ['f4'], ['bd'], ['a0'], ['9c'], ['9b']]
#
# The state of message 2  after shifting rows is:  [['cd'], ['3f'], ['46'], ['c1'], ['e9'], ['04'], ['d2'], ['0b'], ['eb'], ['36'], ['3a'], ['93'], ['ae'], ['a8'], ['24'], ['28']]
#
# The state of message 3  after shifting rows is:  [['0d'], ['e7'], ['95'], ['93'], ['41'], ['55'], ['f5'], ['c7'], ['96'], ['b2'], ['85'], ['e8'], ['af'], ['6d'], ['84'], ['bc']]
#
# The state of message 4  after shifting rows is:  [['cd'], ['05'], ['25'], ['62'], ['f3'], ['cd'], ['f2'], ['9b'], ['f2'], ['12'], ['30'], ['db'], ['8b'], ['98'], ['12'], ['57']]
#
# The state of message 5  after shifting rows is:  [['e2'], ['05'], ['28'], ['d0'], ['5a'], ['77'], ['b5'], ['7b'], ['ee'], ['bb'], ['0a'], ['9f'], ['2b'], ['d9'], ['a0'], ['48']]
#
#
#
# MIX COLUMNS:
#
#
# The state of message 1  after mixing columns is:  [['15'], ['ce'], ['89'], ['65'], ['c9'], ['4d'], ['71'], ['47'], ['7f'], ['4b'], ['be'], ['97'], ['9d'], ['c2'], ['88'], ['cd']]
#
# The state of message 2  after mixing columns is:  [['47'], ['b8'], ['26'], ['ac'], ['1c'], ['87'], ['4f'], ['e0'], ['3e'], ['5a'], ['7'], ['17'], ['a8'], ['a1'], ['36'], ['35']]
#
# The state of message 3  after mixing columns is:  [['2e'], ['ef'], ['75'], ['58'], ['4f'], ['28'], ['b7'], ['f6'], ['97'], ['95'], ['16'], ['5d'], ['ca'], ['5e'], ['e'], ['60']]
#
# The state of message 4  after mixing columns is:  [['c9'], ['ca'], ['24'], ['a8'], ['d8'], ['e4'], ['77'], ['1c'], ['22'], ['5d'], ['f6'], ['82'], ['fb'], ['c1'], ['ce'], ['a2']]
#
# The state of message 5  after mixing columns is:  [['28'], ['40'], ['dc'], ['ab'], ['e3'], ['b'], ['d1'], ['da'], ['84'], ['2'], ['fb'], ['bd'], ['ce'], ['31'], ['71'], ['94']]
#
#
#
# Add Round Keys:
#
#
# The state of message 1  after adding roundkey is:  [['43'], ['c6'], ['a9'], ['62'], ['e'], ['57'], ['c0'], ['c8'], ['9'], ['8'], ['eb'], ['fe'], ['3d'], ['f8'], ['7f'], ['37']]
#
# The state of message 2  after adding roundkey is:  [['11'], ['b0'], ['6'], ['ab'], ['db'], ['9d'], ['fe'], ['6f'], ['48'], ['19'], ['52'], ['7e'], ['8'], ['9b'], ['c1'], ['cf']]
#
# The state of message 3  after adding roundkey is:  [['78'], ['e7'], ['55'], ['5f'], ['88'], ['32'], ['6'], ['79'], ['e1'], ['d6'], ['43'], ['34'], ['6a'], ['64'], ['f9'], ['9a']]
#
# The state of message 4  after adding roundkey is:  [['9f'], ['c2'], ['4'], ['af'], ['1f'], ['fe'], ['c6'], ['93'], ['54'], ['1e'], ['a3'], ['eb'], ['5b'], ['fb'], ['39'], ['58']]
#
# The state of message 5  after adding roundkey is:  [['7e'], ['48'], ['fc'], ['ac'], ['24'], ['11'], ['60'], ['55'], ['f2'], ['41'], ['ae'], ['d4'], ['6e'], ['b'], ['86'], ['6e']]
#
#
#
# ##### END OF ROUND  2 : ######
#
#
#
#
# ##### START OF ROUND  3 : ######
#
#
#
#
# SUBSTITUTION:
#
#
# The state of message 1  after substitution is:  [['1a'], ['b4'], ['d3'], ['aa'], ['ab'], ['5b'], ['ba'], ['e8'], ['01'], ['30'], ['e9'], ['bb'], ['27'], ['41'], ['d2'], ['9a']]
#
# The state of message 2  after substitution is:  [['82'], ['e7'], ['6f'], ['62'], ['b9'], ['5e'], ['bb'], ['a8'], ['52'], ['d4'], ['00'], ['f3'], ['30'], ['14'], ['78'], ['8a']]
#
# The state of message 3  after substitution is:  [['bc'], ['94'], ['fc'], ['cf'], ['c4'], ['23'], ['6f'], ['b6'], ['f8'], ['f6'], ['1a'], ['18'], ['02'], ['43'], ['99'], ['b8']]
#
# The state of message 4  after substitution is:  [['db'], ['25'], ['f2'], ['79'], ['c0'], ['bb'], ['b4'], ['dc'], ['20'], ['72'], ['0a'], ['e9'], ['39'], ['0f'], ['12'], ['6a']]
#
# The state of message 5  after substitution is:  [['f3'], ['52'], ['b0'], ['91'], ['36'], ['82'], ['d0'], ['fc'], ['89'], ['83'], ['e4'], ['48'], ['9f'], ['2b'], ['44'], ['9f']]
#
#
#
# SHIFT ROWS:
#
#
# The state of message 1  after shifting rows is:  [['1a'], ['5b'], ['e9'], ['9a'], ['ab'], ['30'], ['d2'], ['aa'], ['01'], ['41'], ['d3'], ['e8'], ['27'], ['b4'], ['ba'], ['bb']]
#
# The state of message 2  after shifting rows is:  [['82'], ['5e'], ['00'], ['8a'], ['b9'], ['d4'], ['78'], ['62'], ['52'], ['14'], ['6f'], ['a8'], ['30'], ['e7'], ['bb'], ['f3']]
#
# The state of message 3  after shifting rows is:  [['bc'], ['23'], ['1a'], ['b8'], ['c4'], ['f6'], ['99'], ['cf'], ['f8'], ['43'], ['fc'], ['b6'], ['02'], ['94'], ['6f'], ['18']]
#
# The state of message 4  after shifting rows is:  [['db'], ['bb'], ['0a'], ['6a'], ['c0'], ['72'], ['12'], ['79'], ['20'], ['0f'], ['f2'], ['dc'], ['39'], ['25'], ['b4'], ['e9']]
#
# The state of message 5  after shifting rows is:  [['f3'], ['82'], ['e4'], ['9f'], ['36'], ['83'], ['44'], ['91'], ['89'], ['2b'], ['b0'], ['fc'], ['9f'], ['52'], ['d0'], ['48']]
#
#
#
# MIX COLUMNS:
#
#
# The state of message 1  after mixing columns is:  [['aa'], ['16'], ['3d'], ['b3'], ['65'], ['c'], ['c1'], ['4b'], ['fa'], ['5'], ['de'], ['5a'], ['88'], ['3a'], ['2a'], ['a']]
#
# The state of message 2  after mixing columns is:  [['77'], ['b4'], ['59'], ['cc'], ['14'], ['e0'], ['3b'], ['b8'], ['5f'], ['63'], ['7b'], ['c6'], ['1a'], ['c0'], ['b4'], ['f1']]
#
# The state of message 3  after mixing columns is:  [['a4'], ['6c'], ['78'], ['8d'], ['c4'], ['4c'], ['51'], ['bd'], ['64'], ['d7'], ['99'], ['db'], ['d4'], ['98'], ['60'], ['cd']]
#
# The state of message 4  after mixing columns is:  [['1b'], ['c2'], ['ca'], ['13'], ['66'], ['6b'], ['1d'], ['c9'], ['7f'], ['ef'], ['af'], ['3e'], ['40'], ['5d'], ['4f'], ['13']]
#
# The state of message 5  after mixing columns is:  [['1b'], ['44'], ['18'], ['4d'], ['27'], ['76'], ['95'], ['a4'], ['38'], ['e8'], ['c6'], ['f8'], ['4b'], ['18'], ['ae'], ['a8']]
#
#
#
# Add Round Keys:
#
#
# The state of message 1  after adding roundkey is:  [['78'], ['76'], ['30'], ['54'], ['70'], ['76'], ['7d'], ['23'], ['99'], ['3c'], ['37'], ['5b'], ['4b'], ['39'], ['34'], ['f1']]
#
# The state of message 2  after adding roundkey is:  [['a5'], ['d4'], ['54'], ['2b'], ['1'], ['9a'], ['87'], ['d0'], ['3c'], ['5a'], ['92'], ['c7'], ['d9'], ['c3'], ['aa'], ['a']]
#
# The state of message 3  after adding roundkey is:  [['76'], ['c'], ['75'], ['6a'], ['d1'], ['36'], ['ed'], ['d5'], ['7'], ['ee'], ['70'], ['da'], ['17'], ['9b'], ['7e'], ['36']]
#
# The state of message 4  after adding roundkey is:  [['c9'], ['a2'], ['c7'], ['f4'], ['73'], ['11'], ['a1'], ['a1'], ['1c'], ['d6'], ['46'], ['3f'], ['83'], ['5e'], ['51'], ['e8']]
#
# The state of message 5  after adding roundkey is:  [['c9'], ['24'], ['15'], ['aa'], ['32'], ['c'], ['29'], ['cc'], ['5b'], ['d1'], ['2f'], ['f9'], ['88'], ['1b'], ['b0'], ['53']]
#
#
#
# ##### END OF ROUND  3 : ######
#
#
#
#
# ##### START OF ROUND  4 : ######
#
#
#
#
# SUBSTITUTION:
#
#
# The state of message 1  after substitution is:  [['bc'], ['38'], ['04'], ['20'], ['51'], ['38'], ['ff'], ['26'], ['ee'], ['eb'], ['9a'], ['39'], ['b3'], ['12'], ['18'], ['a1']]
#
# The state of message 2  after substitution is:  [['06'], ['48'], ['20'], ['f1'], ['7c'], ['b8'], ['17'], ['70'], ['eb'], ['be'], ['4f'], ['c6'], ['35'], ['2e'], ['ac'], ['67']]
#
# The state of message 3  after substitution is:  [['38'], ['fe'], ['9d'], ['02'], ['3e'], ['05'], ['55'], ['03'], ['c5'], ['28'], ['51'], ['57'], ['f0'], ['14'], ['f3'], ['05']]
#
# The state of message 4  after substitution is:  [['dd'], ['3a'], ['c6'], ['bf'], ['8f'], ['82'], ['32'], ['32'], ['9c'], ['f6'], ['5a'], ['75'], ['ec'], ['58'], ['d1'], ['9b']]
#
# The state of message 5  after substitution is:  [['dd'], ['36'], ['59'], ['ac'], ['23'], ['fe'], ['a5'], ['4b'], ['39'], ['3e'], ['15'], ['99'], ['c4'], ['af'], ['e7'], ['ed']]
#
#
#
# SHIFT ROWS:
#
#
# The state of message 1  after shifting rows is:  [['bc'], ['38'], ['9a'], ['a1'], ['51'], ['eb'], ['18'], ['20'], ['ee'], ['12'], ['04'], ['26'], ['b3'], ['38'], ['ff'], ['39']]
#
# The state of message 2  after shifting rows is:  [['06'], ['b8'], ['4f'], ['67'], ['7c'], ['be'], ['ac'], ['f1'], ['eb'], ['2e'], ['20'], ['70'], ['35'], ['48'], ['17'], ['c6']]
#
# The state of message 3  after shifting rows is:  [['38'], ['05'], ['51'], ['05'], ['3e'], ['28'], ['f3'], ['02'], ['c5'], ['14'], ['9d'], ['03'], ['f0'], ['fe'], ['55'], ['57']]
#
# The state of message 4  after shifting rows is:  [['dd'], ['82'], ['5a'], ['9b'], ['8f'], ['f6'], ['d1'], ['bf'], ['9c'], ['58'], ['c6'], ['32'], ['ec'], ['3a'], ['32'], ['75']]
#
# The state of message 5  after shifting rows is:  [['dd'], ['fe'], ['15'], ['ed'], ['23'], ['3e'], ['e7'], ['ac'], ['39'], ['af'], ['59'], ['4b'], ['c4'], ['36'], ['a5'], ['99']]
#
#
#
# MIX COLUMNS:
#
#
# The state of message 1  after mixing columns is:  [['10'], ['d8'], ['53'], ['24'], ['bc'], ['94'], ['ea'], ['40'], ['d3'], ['e0'], ['9e'], ['73'], ['f3'], ['e0'], ['25'], ['7b']]
#
# The state of message 2  after mixing columns is:  [['f7'], ['db'], ['89'], ['33'], ['7c'], ['5'], ['89'], ['6f'], ['ef'], ['a7'], ['15'], ['c8'], ['63'], ['5a'], ['2'], ['97']]
#
# The state of message 3  after mixing columns is:  [['2b'], ['c4'], ['90'], ['16'], ['f5'], ['62'], ['ed'], ['9d'], ['33'], ['52'], ['f5'], ['db'], ['e0'], ['bf'], ['5d'], ['e']]
#
# The state of message 4  after mixing columns is:  [['fd'], ['b7'], ['5d'], ['89'], ['6a'], ['af'], ['1a'], ['c8'], ['3f'], ['4f'], ['5'], ['45'], ['ca'], ['bb'], ['2d'], ['cd']]
#
# The state of message 5  after mixing columns is:  [['40'], ['e8'], ['25'], ['56'], ['4f'], ['c1'], ['27'], ['ff'], ['8a'], ['dc'], ['f9'], ['2b'], ['f5'], ['c5'], ['13'], ['ed']]
#
#
#
# Add Round Keys:
#
#
# The state of message 1  after adding roundkey is:  [['b1'], ['ca'], ['51'], ['ed'], ['8'], ['fc'], ['54'], ['e1'], ['4'], ['b1'], ['c9'], ['d3'], ['e7'], ['b2'], ['6c'], ['20']]
#
# The state of message 2  after adding roundkey is:  [['56'], ['c9'], ['8b'], ['fa'], ['c8'], ['6d'], ['37'], ['ce'], ['38'], ['f6'], ['42'], ['68'], ['77'], ['8'], ['4b'], ['cc']]
#
# The state of message 3  after adding roundkey is:  [['8a'], ['d6'], ['92'], ['df'], ['41'], ['a'], ['53'], ['3c'], ['e4'], ['3'], ['a2'], ['7b'], ['f4'], ['ed'], ['14'], ['55']]
#
# The state of message 4  after adding roundkey is:  [['5c'], ['a5'], ['5f'], ['40'], ['de'], ['c7'], ['a4'], ['69'], ['e8'], ['1e'], ['52'], ['e5'], ['de'], ['e9'], ['64'], ['96']]
#
# The state of message 5  after adding roundkey is:  [['e1'], ['fa'], ['27'], ['9f'], ['fb'], ['a9'], ['99'], ['5e'], ['5d'], ['8d'], ['ae'], ['8b'], ['e1'], ['97'], ['5a'], ['b6']]
#
#
#
# ##### END OF ROUND  4 : ######
#
#
#
#
# ##### START OF ROUND  5 : ######
#
#
#
#
# SUBSTITUTION:
#
#
# The state of message 1  after substitution is:  [['c8'], ['74'], ['d1'], ['55'], ['30'], ['b0'], ['20'], ['f8'], ['f2'], ['c8'], ['dd'], ['66'], ['94'], ['37'], ['50'], ['b7']]
#
# The state of message 2  after substitution is:  [['b1'], ['dd'], ['3d'], ['2d'], ['e8'], ['3c'], ['9a'], ['8b'], ['07'], ['42'], ['2c'], ['45'], ['f5'], ['30'], ['b3'], ['4b']]
#
# The state of message 3  after substitution is:  [['7e'], ['f6'], ['4f'], ['9e'], ['83'], ['67'], ['ed'], ['eb'], ['69'], ['7b'], ['3a'], ['21'], ['bf'], ['55'], ['fa'], ['fc']]
#
# The state of message 4  after substitution is:  [['4a'], ['06'], ['cf'], ['09'], ['1d'], ['c6'], ['49'], ['f9'], ['9b'], ['72'], ['00'], ['d9'], ['1d'], ['1e'], ['43'], ['90']]
#
# The state of message 5  after substitution is:  [['f8'], ['2d'], ['cc'], ['db'], ['0f'], ['d3'], ['ee'], ['58'], ['4c'], ['5d'], ['e4'], ['3d'], ['f8'], ['88'], ['be'], ['4e']]
#
#
#
# SHIFT ROWS:
#
#
# The state of message 1  after shifting rows is:  [['c8'], ['b0'], ['dd'], ['b7'], ['30'], ['c8'], ['50'], ['55'], ['f2'], ['37'], ['d1'], ['f8'], ['94'], ['74'], ['20'], ['66']]
#
# The state of message 2  after shifting rows is:  [['b1'], ['3c'], ['2c'], ['4b'], ['e8'], ['42'], ['b3'], ['2d'], ['07'], ['30'], ['3d'], ['8b'], ['f5'], ['dd'], ['9a'], ['45']]
#
# The state of message 3  after shifting rows is:  [['7e'], ['67'], ['3a'], ['fc'], ['83'], ['7b'], ['fa'], ['9e'], ['69'], ['55'], ['4f'], ['eb'], ['bf'], ['f6'], ['ed'], ['21']]
#
# The state of message 4  after shifting rows is:  [['4a'], ['c6'], ['00'], ['90'], ['1d'], ['72'], ['43'], ['09'], ['9b'], ['1e'], ['cf'], ['f9'], ['1d'], ['06'], ['49'], ['d9']]
#
# The state of message 5  after shifting rows is:  [['f8'], ['d3'], ['e4'], ['4e'], ['0f'], ['5d'], ['be'], ['db'], ['4c'], ['88'], ['cc'], ['58'], ['f8'], ['2d'], ['ee'], ['3d']]
#
#
#
# MIX COLUMNS:
#
#
# The state of message 1  after mixing columns is:  [['2a'], ['78'], ['1b'], ['5b'], ['26'], ['1e'], ['a7'], ['62'], ['8f'], ['c'], ['6f'], ['0'], ['e9'], ['7a'], ['a'], ['3f']]
#
# The state of message 2  after mixing columns is:  [['5a'], ['f6'], ['8'], ['4e'], ['93'], ['8f'], ['a0'], ['88'], ['e8'], ['ab'], ['cb'], ['9'], ['52'], ['a4'], ['c8'], ['c9']]
#
# The state of message 3  after mixing columns is:  [['93'], ['2'], ['72'], ['3c'], ['f4'], ['fe'], ['ae'], ['38'], ['89'], ['f9'], ['84'], ['6c'], ['a8'], ['45'], ['eb'], ['83']]
#
# The state of message 4  after mixing columns is:  [['55'], ['4d'], ['27'], ['23'], ['e6'], ['35'], ['f2'], ['4'], ['39'], ['14'], ['10'], ['8e'], ['a0'], ['13'], ['f9'], ['c1']]
#
# The state of message 5  after mixing columns is:  [['2f'], ['3c'], ['2a'], ['b8'], ['9c'], ['b7'], ['43'], ['5f'], ['8f'], ['50'], ['af'], ['20'], ['4f'], ['b6'], ['55'], ['aa']]
#
#
#
# Add Round Keys:
#
#
# The state of message 1  after adding roundkey is:  [['9b'], ['51'], ['20'], ['68'], ['23'], ['5f'], ['22'], ['f0'], ['5d'], ['1c'], ['bd'], ['32'], ['2f'], ['38'], ['91'], ['56']]
#
# The state of message 2  after adding roundkey is:  [['eb'], ['df'], ['33'], ['7d'], ['96'], ['ce'], ['25'], ['1a'], ['3a'], ['bb'], ['19'], ['3b'], ['94'], ['e6'], ['53'], ['a0']]
#
# The state of message 3  after adding roundkey is:  [['22'], ['2b'], ['49'], ['f'], ['f1'], ['bf'], ['2b'], ['aa'], ['5b'], ['e9'], ['56'], ['5e'], ['6e'], ['7'], ['70'], ['ea']]
#
# The state of message 4  after adding roundkey is:  [['e4'], ['64'], ['1c'], ['10'], ['e3'], ['74'], ['77'], ['96'], ['eb'], ['4'], ['c2'], ['bc'], ['66'], ['51'], ['62'], ['a8']]
#
# The state of message 5  after adding roundkey is:  [['9e'], ['15'], ['11'], ['8b'], ['99'], ['f6'], ['c6'], ['cd'], ['5d'], ['40'], ['7d'], ['12'], ['89'], ['f4'], ['ce'], ['c3']]
#
#
#
# ##### END OF ROUND  5 : ######
#
#
#
#
# ##### START OF ROUND  6 : ######
#
#
#
#
# SUBSTITUTION:
#
#
# The state of message 1  after substitution is:  [['14'], ['d1'], ['b7'], ['45'], ['26'], ['cf'], ['93'], ['8c'], ['4c'], ['9c'], ['7a'], ['23'], ['15'], ['07'], ['81'], ['b1']]
#
# The state of message 2  after substitution is:  [['e9'], ['9e'], ['c3'], ['ff'], ['90'], ['8b'], ['3f'], ['a2'], ['80'], ['ea'], ['d4'], ['e2'], ['22'], ['8e'], ['ed'], ['e0']]
#
# The state of message 3  after substitution is:  [['93'], ['f1'], ['3b'], ['76'], ['a1'], ['08'], ['f1'], ['ac'], ['39'], ['1e'], ['b1'], ['58'], ['9f'], ['c5'], ['51'], ['87']]
#
# The state of message 4  after substitution is:  [['69'], ['43'], ['9c'], ['ca'], ['11'], ['92'], ['f5'], ['90'], ['e9'], ['f2'], ['25'], ['65'], ['33'], ['d1'], ['aa'], ['c2']]
#
# The state of message 5  after substitution is:  [['0b'], ['59'], ['82'], ['3d'], ['ee'], ['42'], ['b4'], ['bd'], ['4c'], ['09'], ['ff'], ['c9'], ['a7'], ['bf'], ['8b'], ['2e']]
#
#
#
# SHIFT ROWS:
#
#
# The state of message 1  after shifting rows is:  [['14'], ['cf'], ['7a'], ['b1'], ['26'], ['9c'], ['81'], ['45'], ['4c'], ['07'], ['b7'], ['8c'], ['15'], ['d1'], ['93'], ['23']]
#
# The state of message 2  after shifting rows is:  [['e9'], ['8b'], ['d4'], ['e0'], ['90'], ['ea'], ['ed'], ['ff'], ['80'], ['8e'], ['c3'], ['a2'], ['22'], ['9e'], ['3f'], ['e2']]
#
# The state of message 3  after shifting rows is:  [['93'], ['08'], ['b1'], ['87'], ['a1'], ['1e'], ['51'], ['76'], ['39'], ['c5'], ['3b'], ['ac'], ['9f'], ['f1'], ['f1'], ['58']]
#
# The state of message 4  after shifting rows is:  [['69'], ['92'], ['25'], ['c2'], ['11'], ['f2'], ['aa'], ['ca'], ['e9'], ['d1'], ['9c'], ['90'], ['33'], ['43'], ['f5'], ['65']]
#
# The state of message 5  after shifting rows is:  [['0b'], ['42'], ['ff'], ['2e'], ['ee'], ['09'], ['8b'], ['3d'], ['4c'], ['bf'], ['82'], ['bd'], ['a7'], ['59'], ['b4'], ['c9']]
#
#
#
# MIX COLUMNS:
#
#
# The state of message 1  after mixing columns is:  [['a9'], ['ae'], ['e7'], ['f0'], ['37'], ['d8'], ['6c'], ['fd'], ['aa'], ['c'], ['b1'], ['67'], ['f2'], ['21'], ['9c'], ['3b']]
#
# The state of message 2  after mixing columns is:  [['7b'], ['63'], ['ea'], ['a4'], ['c'], ['8c'], ['a1'], ['49'], ['f3'], ['7b'], ['6e'], ['89'], ['20'], ['a6'], ['ff'], ['18']]
#
# The state of message 3  after mixing columns is:  [['13'], ['cc'], ['70'], ['2'], ['5c'], ['18'], ['87'], ['5b'], ['b1'], ['49'], ['65'], ['f6'], ['84'], ['36'], ['7f'], ['a']]
#
# The state of message 4  after mixing columns is:  [['98'], ['fb'], ['ec'], ['93'], ['4f'], ['c1'], ['e9'], ['e4'], ['ad'], ['7f'], ['b0'], ['56'], ['33'], ['d4'], ['2e'], ['29']]
#
# The state of message 5  after mixing columns is:  [['1'], ['bb'], ['de'], ['fc'], ['6a'], ['47'], ['ad'], ['d1'], ['7d'], ['9'], ['30'], ['88'], ['c3'], ['1b'], ['cd'], ['96']]
#
#
#
# Add Round Keys:
#
#
# The state of message 1  after adding roundkey is:  [['14'], ['93'], ['25'], ['77'], ['8f'], ['a4'], ['2b'], ['e8'], ['c0'], ['60'], ['24'], ['40'], ['5e'], ['f'], ['92'], ['75']]
#
# The state of message 2  after adding roundkey is:  [['c6'], ['5e'], ['28'], ['23'], ['b4'], ['f0'], ['e6'], ['5c'], ['99'], ['17'], ['fb'], ['ae'], ['8c'], ['88'], ['f1'], ['56']]
#
# The state of message 3  after adding roundkey is:  [['ae'], ['f1'], ['b2'], ['85'], ['e4'], ['64'], ['c0'], ['4e'], ['db'], ['25'], ['f0'], ['d1'], ['28'], ['18'], ['71'], ['44']]
#
# The state of message 4  after adding roundkey is:  [['25'], ['c6'], ['2e'], ['14'], ['f7'], ['bd'], ['ae'], ['f1'], ['c7'], ['13'], ['25'], ['71'], ['9f'], ['fa'], ['20'], ['67']]
#
# The state of message 5  after adding roundkey is:  [['bc'], ['86'], ['1c'], ['7b'], ['d2'], ['3b'], ['ea'], ['c4'], ['17'], ['65'], ['a5'], ['af'], ['6f'], ['35'], ['c3'], ['d8']]
#
#
#
# ##### END OF ROUND  6 : ######
#
#
#
#
# ##### START OF ROUND  7 : ######
#
#
#
#
# SUBSTITUTION:
#
#
# The state of message 1  after substitution is:  [['fa'], ['dc'], ['3f'], ['f5'], ['73'], ['49'], ['f1'], ['9b'], ['ba'], ['d0'], ['36'], ['09'], ['58'], ['76'], ['4f'], ['9d']]
#
# The state of message 2  after substitution is:  [['b4'], ['58'], ['34'], ['26'], ['8d'], ['8c'], ['8e'], ['4a'], ['ee'], ['f0'], ['0f'], ['e4'], ['64'], ['c4'], ['a1'], ['b1']]
#
# The state of message 3  after substitution is:  [['e4'], ['a1'], ['37'], ['97'], ['69'], ['43'], ['ba'], ['2f'], ['b9'], ['3f'], ['8c'], ['3e'], ['34'], ['ad'], ['a3'], ['1b']]
#
# The state of message 4  after substitution is:  [['3f'], ['b4'], ['31'], ['fa'], ['68'], ['7a'], ['e4'], ['a1'], ['c6'], ['7d'], ['3f'], ['a3'], ['db'], ['2d'], ['b7'], ['85']]
#
# The state of message 5  after substitution is:  [['65'], ['44'], ['9c'], ['21'], ['b5'], ['e2'], ['87'], ['1c'], ['f0'], ['4d'], ['06'], ['79'], ['a8'], ['96'], ['2e'], ['61']]
#
#
#
# SHIFT ROWS:
#
#
# The state of message 1  after shifting rows is:  [['fa'], ['49'], ['36'], ['9d'], ['73'], ['d0'], ['4f'], ['f5'], ['ba'], ['76'], ['3f'], ['9b'], ['58'], ['dc'], ['f1'], ['09']]
#
# The state of message 2  after shifting rows is:  [['b4'], ['8c'], ['0f'], ['b1'], ['8d'], ['f0'], ['a1'], ['26'], ['ee'], ['c4'], ['34'], ['4a'], ['64'], ['58'], ['8e'], ['e4']]
#
# The state of message 3  after shifting rows is:  [['e4'], ['43'], ['8c'], ['1b'], ['69'], ['3f'], ['a3'], ['97'], ['b9'], ['ad'], ['37'], ['2f'], ['34'], ['a1'], ['ba'], ['3e']]
#
# The state of message 4  after shifting rows is:  [['3f'], ['7a'], ['3f'], ['85'], ['68'], ['7d'], ['b7'], ['fa'], ['c6'], ['2d'], ['31'], ['a1'], ['db'], ['b4'], ['e4'], ['a3']]
#
# The state of message 5  after shifting rows is:  [['65'], ['e2'], ['06'], ['61'], ['b5'], ['4d'], ['2e'], ['21'], ['f0'], ['96'], ['9c'], ['1c'], ['a8'], ['44'], ['87'], ['79']]
#
#
#
# MIX COLUMNS:
#
#
# The state of message 1  after mixing columns is:  [['9f'], ['af'], ['63'], ['4b'], ['37'], ['ec'], ['39'], ['fb'], ['51'], ['8c'], ['4'], ['b1'], ['37'], ['fa'], ['66'], ['d7']]
#
# The state of message 2  after mixing columns is:  [['42'], ['17'], ['ee'], ['3d'], ['8d'], ['a8'], ['4e'], ['91'], ['ee'], ['6b'], ['9c'], ['4d'], ['4a'], ['b9'], ['c'], ['a9']]
#
# The state of message 3  after mixing columns is:  [['81'], ['f6'], ['89'], ['ce'], ['a7'], ['7e'], ['a9'], ['12'], ['9d'], ['8e'], ['b'], ['14'], ['14'], ['86'], ['b8'], ['3b']]
#
# The state of message 4  after mixing columns is:  [['4a'], ['f'], ['af'], ['15'], ['1a'], ['aa'], ['75'], ['9d'], ['70'], ['6e'], ['71'], ['14'], ['2d'], ['3c'], ['42'], ['7b']]
#
# The state of message 5  after mixing columns is:  [['90'], ['d1'], ['28'], ['89'], ['a9'], ['7c'], ['c7'], ['e5'], ['da'], ['64'], ['61'], ['39'], ['79'], ['cb'], ['72'], ['d2']]
#
#
#
# Add Round Keys:
#
#
# The state of message 1  after adding roundkey is:  [['53'], ['39'], ['8e'], ['5d'], ['43'], ['6'], ['93'], ['f8'], ['4f'], ['a'], ['3b'], ['95'], ['85'], ['52'], ['57'], ['bd']]
#
# The state of message 2  after adding roundkey is:  [['8e'], ['81'], ['3'], ['2b'], ['f9'], ['42'], ['e4'], ['92'], ['f0'], ['ed'], ['a3'], ['69'], ['f8'], ['11'], ['3d'], ['c3']]
#
# The state of message 3  after adding roundkey is:  [['4d'], ['60'], ['64'], ['d8'], ['d3'], ['94'], ['3'], ['11'], ['83'], ['8'], ['34'], ['30'], ['a6'], ['2e'], ['89'], ['51']]
#
# The state of message 4  after adding roundkey is:  [['86'], ['99'], ['42'], ['3'], ['6e'], ['40'], ['df'], ['9e'], ['6e'], ['e8'], ['4e'], ['30'], ['9f'], ['94'], ['73'], ['11']]
#
# The state of message 5  after adding roundkey is:  [['5c'], ['47'], ['c5'], ['9f'], ['dd'], ['96'], ['6d'], ['e6'], ['c4'], ['e2'], ['5e'], ['1d'], ['cb'], ['63'], ['43'], ['b8']]
#
#
#
# ##### END OF ROUND  7 : ######
#
#
#
#
# ##### START OF ROUND  8 : ######
#
#
#
#
# SUBSTITUTION:
#
#
# The state of message 1  after substitution is:  [['ed'], ['12'], ['19'], ['4c'], ['1a'], ['6f'], ['dc'], ['41'], ['84'], ['67'], ['e2'], ['2a'], ['97'], ['00'], ['5b'], ['7a']]
#
# The state of message 2  after substitution is:  [['19'], ['0c'], ['7b'], ['f1'], ['99'], ['2c'], ['69'], ['4f'], ['8c'], ['55'], ['0a'], ['f9'], ['41'], ['82'], ['27'], ['2e']]
#
# The state of message 3  after substitution is:  [['e3'], ['d0'], ['43'], ['61'], ['66'], ['22'], ['7b'], ['82'], ['ec'], ['30'], ['18'], ['04'], ['24'], ['31'], ['a7'], ['d1']]
#
# The state of message 4  after substitution is:  [['44'], ['ee'], ['2c'], ['7b'], ['9f'], ['09'], ['9e'], ['0b'], ['9f'], ['9b'], ['2f'], ['04'], ['db'], ['22'], ['8f'], ['82']]
#
# The state of message 5  after substitution is:  [['4a'], ['a0'], ['a6'], ['db'], ['c1'], ['90'], ['3c'], ['8e'], ['1c'], ['98'], ['58'], ['a4'], ['1f'], ['fb'], ['1a'], ['6c']]
#
#
#
# SHIFT ROWS:
#
#
# The state of message 1  after shifting rows is:  [['ed'], ['6f'], ['e2'], ['7a'], ['1a'], ['67'], ['5b'], ['4c'], ['84'], ['00'], ['19'], ['41'], ['97'], ['12'], ['dc'], ['2a']]
#
# The state of message 2  after shifting rows is:  [['19'], ['2c'], ['0a'], ['2e'], ['99'], ['55'], ['27'], ['f1'], ['8c'], ['82'], ['7b'], ['4f'], ['41'], ['0c'], ['69'], ['f9']]
#
# The state of message 3  after shifting rows is:  [['e3'], ['22'], ['18'], ['d1'], ['66'], ['30'], ['a7'], ['61'], ['ec'], ['31'], ['43'], ['82'], ['24'], ['d0'], ['7b'], ['04']]
#
# The state of message 4  after shifting rows is:  [['44'], ['09'], ['2f'], ['82'], ['9f'], ['9b'], ['8f'], ['7b'], ['9f'], ['22'], ['2c'], ['0b'], ['db'], ['ee'], ['9e'], ['04']]
#
# The state of message 5  after shifting rows is:  [['4a'], ['90'], ['58'], ['6c'], ['c1'], ['98'], ['1a'], ['db'], ['1c'], ['fb'], ['a6'], ['8e'], ['1f'], ['a0'], ['3c'], ['a4']]
#
#
#
# MIX COLUMNS:
#
#
# The state of message 1  after mixing columns is:  [['e8'], ['74'], ['d3'], ['55'], ['8a'], ['75'], ['1f'], ['8a'], ['4b'], ['ee'], ['75'], ['c'], ['f5'], ['e6'], ['58'], ['38']]
#
# The state of message 2  after mixing columns is:  [['62'], ['71'], ['53'], ['51'], ['0'], ['ab'], ['8a'], ['3b'], ['aa'], ['51'], ['29'], ['e8'], ['6'], ['1b'], ['8f'], ['4f']]
#
# The state of message 3  after mixing columns is:  [['72'], ['5e'], ['99'], ['bd'], ['5a'], ['95'], ['a0'], ['ff'], ['51'], ['c9'], ['c6'], ['42'], ['5c'], ['16'], ['e'], ['cf']]
#
# The state of message 4  after mixing columns is:  [['3e'], ['a5'], ['8e'], ['f5'], ['67'], ['43'], ['8c'], ['58'], ['64'], ['a4'], ['f8'], ['a2'], ['1e'], ['a1'], ['1e'], ['e']]
#
# The state of message 5  after mixing columns is:  [['b'], ['f5'], ['de'], ['ce'], ['eb'], ['1f'], ['1b'], ['77'], ['6'], ['8e'], ['39'], ['7e'], ['5d'], ['a4'], ['30'], ['ee']]
#
#
#
# Add Round Keys:
#
#
# The state of message 1  after adding roundkey is:  [['66'], ['25'], ['3c'], ['74'], ['70'], ['ce'], ['5a'], ['a8'], ['af'], ['d3'], ['f'], ['a'], ['a3'], ['73'], ['13'], ['54']]
#
# The state of message 2  after adding roundkey is:  [['ec'], ['20'], ['bc'], ['70'], ['fa'], ['10'], ['cf'], ['19'], ['4e'], ['6c'], ['53'], ['ee'], ['50'], ['8e'], ['c4'], ['23']]
#
# The state of message 3  after adding roundkey is:  [['fc'], ['f'], ['76'], ['9c'], ['a0'], ['2e'], ['e5'], ['dd'], ['b5'], ['f4'], ['bc'], ['44'], ['a'], ['83'], ['45'], ['a3']]
#
# The state of message 4  after adding roundkey is:  [['b0'], ['f4'], ['61'], ['d4'], ['9d'], ['f8'], ['c9'], ['7a'], ['80'], ['99'], ['82'], ['a4'], ['48'], ['34'], ['55'], ['62']]
#
# The state of message 5  after adding roundkey is:  [['85'], ['a4'], ['31'], ['ef'], ['11'], ['a4'], ['5e'], ['55'], ['e2'], ['b3'], ['43'], ['78'], ['b'], ['31'], ['7b'], ['82']]
#
#
#
# ##### END OF ROUND  8 : ######
#
#
#
#
# ##### START OF ROUND  9 : ######
# SUBSTITUTION:
#
#
# The state of message 1  after substitution is:  [['33'], ['3f'], ['eb'], ['92'], ['51'], ['8b'], ['be'], ['c2'], ['79'], ['66'], ['76'], ['67'], ['0a'], ['8f'], ['7d'], ['20']]
#
# The state of message 2  after substitution is:  [['ce'], ['b7'], ['65'], ['51'], ['2d'], ['ca'], ['8a'], ['d4'], ['2f'], ['50'], ['ed'], ['28'], ['53'], ['19'], ['1c'], ['26']]
#
# The state of message 3  after substitution is:  [['b0'], ['76'], ['38'], ['de'], ['e0'], ['31'], ['d9'], ['c1'], ['d5'], ['bf'], ['65'], ['1b'], ['67'], ['ec'], ['6e'], ['0a']]
#
# The state of message 4  after substitution is:  [['e7'], ['bf'], ['ef'], ['48'], ['5e'], ['41'], ['dd'], ['da'], ['cd'], ['ee'], ['13'], ['49'], ['52'], ['18'], ['fc'], ['aa']]
#
# The state of message 5  after substitution is:  [['97'], ['49'], ['c7'], ['df'], ['82'], ['49'], ['58'], ['fc'], ['98'], ['6d'], ['1a'], ['bc'], ['2b'], ['c7'], ['21'], ['13']]
#
#
#
# SHIFT ROWS:
#
#
# The state of message 1  after shifting rows is:  [['33'], ['8b'], ['76'], ['20'], ['51'], ['66'], ['7d'], ['92'], ['79'], ['8f'], ['eb'], ['c2'], ['0a'], ['3f'], ['be'], ['67']]
#
# The state of message 2  after shifting rows is:  [['ce'], ['ca'], ['ed'], ['26'], ['2d'], ['50'], ['1c'], ['51'], ['2f'], ['19'], ['65'], ['d4'], ['53'], ['b7'], ['8a'], ['28']]
#
# The state of message 3  after shifting rows is:  [['b0'], ['31'], ['65'], ['0a'], ['e0'], ['bf'], ['6e'], ['de'], ['d5'], ['ec'], ['38'], ['c1'], ['67'], ['76'], ['d9'], ['1b']]
#
# The state of message 4  after shifting rows is:  [['e7'], ['41'], ['13'], ['aa'], ['5e'], ['ee'], ['fc'], ['48'], ['cd'], ['18'], ['ef'], ['da'], ['52'], ['bf'], ['dd'], ['49']]
#
# The state of message 5  after shifting rows is:  [['97'], ['49'], ['1a'], ['13'], ['82'], ['6d'], ['21'], ['df'], ['98'], ['c7'], ['c7'], ['fc'], ['2b'], ['49'], ['58'], ['bc']]
#
#
#
# MIX COLUMNS:
#
#
# The state of message 1  after mixing columns is:  [['b6'], ['84'], ['34'], ['e8'], ['e7'], ['88'], ['60'], ['d7'], ['51'], ['98'], ['66'], ['70'], ['8c'], ['ca'], ['fb'], ['51']]
#
# The state of message 2  after mixing columns is:  [['9'], ['4b'], ['af'], ['22'], ['e7'], ['f8'], ['b6'], ['99'], ['c4'], ['66'], ['9b'], ['be'], ['c6'], ['8b'], ['93'], ['98']]
#
# The state of message 3  after mixing columns is:  [['47'], ['77'], ['55'], ['8b'], ['b1'], ['e9'], ['fa'], ['4d'], ['67'], ['9f'], ['11'], ['29'], ['96'], ['e0'], ['95'], ['30']]
#
# The state of message 4  after mixing columns is:  [['af'], ['fa'], ['65'], ['2f'], ['21'], ['ce'], ['8b'], ['60'], ['9c'], ['d'], ['65'], ['14'], ['ea'], ['2'], ['97'], ['6']]
#
# The state of message 5  after mixing columns is:  [['e7'], ['38'], ['df'], ['d7'], ['56'], ['e4'], ['d7'], ['74'], ['42'], ['a3'], ['d5'], ['50'], ['69'], ['ed'], ['d'], ['f']]
#
#
#
# Add Round Keys:
#
#
# The state of message 1  after adding roundkey is:  [['9'], ['66'], ['8b'], ['78'], ['a2'], ['d1'], ['9a'], ['65'], ['f0'], ['fc'], ['e6'], ['c4'], ['7b'], ['3b'], ['30'], ['89']]
#
# The state of message 2  after adding roundkey is:  [['b6'], ['a9'], ['10'], ['b2'], ['a2'], ['a1'], ['4c'], ['2b'], ['65'], ['2'], ['1b'], ['a'], ['31'], ['7a'], ['58'], ['40']]
#
# The state of message 3  after adding roundkey is:  [['f8'], ['95'], ['ea'], ['1b'], ['f4'], ['b0'], ['0'], ['ff'], ['c6'], ['fb'], ['91'], ['9d'], ['61'], ['11'], ['5e'], ['e8']]
#
# The state of message 4  after adding roundkey is:  [['10'], ['18'], ['da'], ['bf'], ['64'], ['97'], ['71'], ['d2'], ['3d'], ['69'], ['e5'], ['a0'], ['1d'], ['f3'], ['5c'], ['de']]
#
# The state of message 5  after adding roundkey is:  [['58'], ['da'], ['60'], ['47'], ['13'], ['bd'], ['2d'], ['c6'], ['e3'], ['c7'], ['55'], ['e4'], ['9e'], ['1c'], ['c6'], ['d7']]
#
#
#
# ##### END OF ROUND  9 : ######
#
#
#
#
# ##### START OF FINAL ROUND : ######
#
#
#
#
# SUBSTITUTION:
#
#
# The state of message 1  after substitution is:  [['01'], ['33'], ['3d'], ['bc'], ['3a'], ['3e'], ['b8'], ['4d'], ['8c'], ['b0'], ['8e'], ['1c'], ['21'], ['e2'], ['04'], ['a7']]
#
# The state of message 2  after substitution is:  [['4e'], ['d3'], ['ca'], ['37'], ['3a'], ['32'], ['29'], ['f1'], ['4d'], ['77'], ['af'], ['67'], ['c7'], ['da'], ['6a'], ['09']]
#
# The state of message 3  after substitution is:  [['41'], ['2a'], ['87'], ['af'], ['bf'], ['e7'], ['63'], ['16'], ['b4'], ['0f'], ['81'], ['5e'], ['ef'], ['82'], ['58'], ['9b']]
#
# The state of message 4  after substitution is:  [['ca'], ['ad'], ['57'], ['08'], ['43'], ['88'], ['a3'], ['b5'], ['27'], ['f9'], ['d9'], ['e0'], ['a4'], ['0d'], ['4a'], ['1d']]
#
# The state of message 5  after substitution is:  [['6a'], ['57'], ['d0'], ['a0'], ['7d'], ['7a'], ['d8'], ['b4'], ['11'], ['c6'], ['fc'], ['69'], ['0b'], ['9c'], ['b4'], ['0e']]
#
#
#
# SHIFT ROWS:
#
#
# The state of message 1  after shifting rows is:  [['01'], ['3e'], ['8e'], ['a7'], ['3a'], ['b0'], ['04'], ['bc'], ['8c'], ['e2'], ['3d'], ['4d'], ['21'], ['33'], ['b8'], ['1c']]
#
# The state of message 2  after shifting rows is:  [['4e'], ['32'], ['af'], ['09'], ['3a'], ['77'], ['6a'], ['37'], ['4d'], ['da'], ['ca'], ['f1'], ['c7'], ['d3'], ['29'], ['67']]
#
# The state of message 3  after shifting rows is:  [['41'], ['e7'], ['81'], ['9b'], ['bf'], ['0f'], ['58'], ['af'], ['b4'], ['82'], ['87'], ['16'], ['ef'], ['2a'], ['63'], ['5e']]
#
# The state of message 4  after shifting rows is:  [['ca'], ['88'], ['d9'], ['1d'], ['43'], ['f9'], ['4a'], ['08'], ['27'], ['0d'], ['57'], ['b5'], ['a4'], ['ad'], ['a3'], ['e0']]
#
# The state of message 5  after shifting rows is:  [['6a'], ['7a'], ['fc'], ['0e'], ['7d'], ['c6'], ['b4'], ['a0'], ['11'], ['9c'], ['d0'], ['b4'], ['0b'], ['57'], ['d8'], ['69']]
#
#
#
# Add Round Keys:
#
#
# The state of message 1  after adding roundkey is:  [['29'], ['c3'], ['50'], ['5f'], ['57'], ['14'], ['20'], ['f6'], ['40'], ['22'], ['99'], ['b3'], ['1a'], ['2'], ['d7'], ['3a']]
#
# The state of message 2  after adding roundkey is:  [['66'], ['cf'], ['71'], ['f1'], ['57'], ['d3'], ['4e'], ['7d'], ['81'], ['1a'], ['6e'], ['f'], ['fc'], ['e2'], ['46'], ['41']]
#
# The state of message 3  after adding roundkey is:  [['69'], ['1a'], ['5f'], ['63'], ['d2'], ['ab'], ['7c'], ['e5'], ['78'], ['42'], ['23'], ['e8'], ['d4'], ['1b'], ['c'], ['78']]
#
# The state of message 4  after adding roundkey is:  [['e2'], ['75'], ['7'], ['e5'], ['2e'], ['5d'], ['6e'], ['42'], ['eb'], ['cd'], ['f3'], ['4b'], ['9f'], ['9c'], ['cc'], ['c6']]
#
# The state of message 5  after adding roundkey is:  [['42'], ['87'], ['22'], ['f6'], ['10'], ['62'], ['90'], ['ea'], ['dd'], ['5c'], ['74'], ['4a'], ['30'], ['66'], ['b7'], ['4f']]
#
# The ENCRYPTION is: 29c3505f571420f6402299b31a2d73a66cf71f157d34e7d811a6effce24641691a5f63d2ab7ce5784223e8d41bc78e2757e52e5d6e42ebcdf34b9f9cccc6428722f6106290eadd5c744a3066b74f
# Done
# Done

# %%
#Pycipher Unit Tests:
#website https://pycipher.readthedocs.io 

#AES Unit Tests:
#key = 'Thats my Kung Fu'
#message = 'Two One Nine Two Thats my Kung Fu but we cant know for sure we will hope'

#Outputs in the pdf file
